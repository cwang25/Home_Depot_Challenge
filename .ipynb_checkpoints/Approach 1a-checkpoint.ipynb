# %%
import time
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
#from sklearn import pipeline, model_selection
from sklearn import pipeline, grid_search
#from sklearn.feature_extraction import DictVectorizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import FeatureUnion
from sklearn.decomposition import TruncatedSVD
#from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_squared_error, make_scorer
#from nltk.metrics import edit_distance
from nltk.stem.porter import *
stemmer = PorterStemmer()
#from nltk.stem.snowball import SnowballStemmer #0.003 improvement but takes twice as long as PorterStemmer
#stemmer = SnowballStemmer('english')
import re
#import enchant
import random
random.seed(2016)
from autocorrect import spell
#import enchant

# %%
df_prod = pd.read_csv("df_prod.csv")

# %%
df_train = pd.read_csv('C:/Users/sneha/Google Drive/Github/DataSet/Kaggle/data/train.csv', encoding="ISO-8859-1")
df_test = pd.read_csv('C:/Users/sneha/Google Drive/Github/DataSet/Kaggle/data/test.csv', encoding="ISO-8859-1") #update here
df_attr = pd.read_csv('C:/Users/sneha/Google Drive/Github/DataSet/Kaggle/data/attributes.csv')
df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]].rename(columns={"value": "brand"})

# %%
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

strNum = {'zero':0,'one':1,'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9}

f = open('spelling.txt','r')
zspell = {}
for line in f:
    a, b = line.strip("\n").split("|")
    zspell[a]=b
f.close()

def text_process(s):
    """
    Takes in a string of text, then performs the following:
    1. Clean up data
    2. Remove all stopwords
    3. Returns a list of the cleaned text  
    
    """
    
    s = re.sub(r"(\w)\.([A-Z])", r"\1 \2", s) #Split words with a.A
    s = re.sub(r"([a-z])([A-Z])", r"\1 \2", s) #Split words with a A
    s = s.lower()
    s = s.replace("  "," ")
    s = re.sub(r"([0-9])( *),( *)([0-9])", r"\1\4", s)
    s = s.replace(","," ")
    s = s.replace("$"," ")
    s = s.replace("?"," ")
    s = s.replace("-"," ")
    s = s.replace("//","/")
    s = s.replace("..",".")
    s = s.replace(" / "," ")
    s = s.replace(" \\ "," ")
    s = s.replace("."," . ")
    s = s.replace("   "," ")
    s = s.replace("  "," ").strip(" ")
    s = re.sub(r"(.*)\.$", r"\1", s) #end period
    s = re.sub(r"(.*)\/$", r"\1", s) #end period
    s = re.sub(r"^\.(.*)", r"\1", s) #start period
    s = re.sub(r"^\/(.*)", r"\1", s) #start slash
    s = re.sub(r"([0-9])([a-z])", r"\1 \2", s)
    s = re.sub(r"([a-z])([0-9])", r"\1 \2", s)
    s = s.replace(" x "," xbi ")
    s = re.sub(r"([a-z])( *)\.( *)([a-z])", r"\1 \4", s)
    s = re.sub(r"([a-z])( *)/( *)([a-z])", r"\1 \4", s)
    s = s.replace("*"," xbi ")
    s = s.replace(" by "," xbi ")
    s = re.sub(r"([0-9])( *)\.( *)([0-9])", r"\1.\4", s)
    s = re.sub(r"([0-9]+)( *)(inches|inch|in|')\.?", r"\1in. ", s)
    s = re.sub(r"([0-9]+)( *)(foot|feet|ft|'')\.?", r"\1ft. ", s)
    s = re.sub(r"([0-9]+)( *)(pounds|pound|lbs|lb)\.?", r"\1lb. ", s)
    s = re.sub(r"([0-9]+)( *)(square|sq) ?\.?(feet|foot|ft)\.?", r"\1sq.ft. ", s)
    s = re.sub(r"([0-9]+)( *)(cubic|cu) ?\.?(feet|foot|ft)\.?", r"\1cu.ft. ", s)
    s = re.sub(r"([0-9]+)( *)(gallons|gallon|gal)\.?", r"\1gal. ", s)
    s = re.sub(r"([0-9]+)( *)(ounces|ounce|oz)\.?", r"\1oz. ", s)
    s = re.sub(r"([0-9]+)( *)(centimeters|cm)\.?", r"\1cm. ", s)
    s = re.sub(r"([0-9]+)( *)(milimeters|mm)\.?", r"\1mm. ", s)
    s = s.replace("°"," degrees ")
    s = re.sub(r"([0-9]+)( *)(degrees|degree)\.?", r"\1deg. ", s)
    s = s.replace(" v "," volts ")
    s = re.sub(r"([0-9]+)( *)(volts|volt)\.?", r"\1volt. ", s)
    s = re.sub(r"([0-9]+)( *)(watts|watt)\.?", r"\1watt. ", s)
    s = re.sub(r"([0-9]+)( *)(amperes|ampere|amps|amp)\.?", r"\1amp. ", s)
    s = s.replace("  "," ")
    s = s.replace(" . "," ")
    
    # Check characters to see if they are in punctuation
    #nopunc = [char for char in s.split() if char not in string.punctuation]

    # Join the characters again to form the string.
    #nopunc = ''.join(nopunc)
    
    #s = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    #s = ''.join(s)
    
    s = (" ").join([z for z in s.split(" ") if z not in stopwords.words('english')])
    s = (" ").join([str(strNum[z]) if z in strNum else z for z in s.split(" ")])
    s = (" ").join([stemmer.stem(z) for z in s.split(" ")])
    s = s.lower()
    s = (" ").join([str(zspell[z]) if z in zspell else z for z in s.split(" ")])
    return s

# %%
df_train['product_title'] = df_train['product_title'].apply(text_process)
df_train['search_term'] = df_train['search_term'].apply(text_process)

# %%
df_test['product_title'] = df_test['product_title'].apply(text_process)
df_test['search_term'] = df_test['search_term'].apply(text_process)

# %%
def text_stem(s):
    if isinstance(s, str):
        print (s)
        s = (" ").join([stemmer.stem(z) for z in s.split(" ")])
        s = s.lower()       
        return s
    else:
        return "null"
    
   
df_brand['brand'] = df_brand['brand'].map(lambda x:text_stem(x))

# %%
import nltk


def prod_title_score(uid, search_term):
    prod_title_list = str(df_train[df_train['product_uid'] == uid ][0:1]['product_title'].values[0]).split()
    #print prod_title_list
    search_term_list = search_term.split()
    total_len = len(search_term_list)
    count = 0
    for word in search_term.split():
        #print (word)

            
        if word in prod_title_list:
            count += 1
    if total_len != 0:
        return count/total_len
    else:
        return 0

# %%
nltk.pos_tag(["BEHR"])[0][1] in ['NNP']
# Out:
# True

# %%
    
df_train['prod_title_score'] = df_train.apply(lambda df_train: prod_title_score(df_train['product_uid'],df_train['search_term'] ) ,axis = 1)

# %%
def prod_title_score_test(uid, search_term):
    
    prod_title_list = str(df_test[df_test['product_uid'] == uid ][0:1]['product_title'].values[0]).split()
    #print prod_title_list
    search_term_list = search_term.split()
    total_len = len(search_term_list)
    count = 0
    for word in search_term.split():
        #print (word)
        pos = nltk.pos_tag(word)
        if pos[0][1] not in ['NN','NNP','NNPS', 'NNS']:
            continue
            
        if word in prod_title_list:
            count += 1
    if total_len != 0:
        return count/total_len
    else:
        return 0
    
df_test['prod_title_score'] = df_test.apply(lambda df_test: prod_title_score_test(df_test['product_uid'],df_test['search_term'] ) ,axis = 1)

# %%
def prod_brand_score(uid, search_term):
    if any(df_brand['product_uid'] == uid) is False:
        return 0
    prod_title_list = df_brand[df_brand['product_uid'] == uid ][0:1]['brand'].values[0].split()
    #print prod_title_list
    search_term_list = search_term.split()
    total_len = len(search_term_list)
    count = 0
    for word in search_term.split():
        #print (word)
        pos = nltk.pos_tag(word)
        if pos[0][1] not in ['NN','NNP','NNPS', 'NNS']:
            continue
        if word in prod_title_list:
            count += 1
    if total_len != 0:
        return count/total_len
    else:
        return 0

df_train['prod_brand_score'] = df_train.apply(lambda df_train: prod_brand_score(df_train['product_uid'],df_train['search_term'] ) ,axis = 1)

# %%
df_test['prod_brand_score'] = df_test.apply(lambda df_test: prod_brand_score(df_test['product_uid'],df_test['search_term'] ) ,axis = 1)

# %%
# Out:
#    id  product_uid                    product_title  \
# 0   1       100001  simpson strong tie 12 gaug angl
# 1   4       100001  simpson strong tie 12 gaug angl
# 2   5       100001  simpson strong tie 12 gaug angl
# 3   6       100001  simpson strong tie 12 gaug angl
# 4   7       100001  simpson strong tie 12 gaug angl
#
#                   search_term  prod_brand_score
# 0              90deg. bracket          0.000000
# 1             metal l bracket          0.000000
# 2             simpson sky abl          0.333333
# 3          simpson strong tie          0.333333
# 4  simpson strong tie hcc 668          0.200000

# %%
df_test.head()
# Out:
#    id  product_uid                    product_title  \
# 0   1       100001  simpson strong tie 12 gaug angl
# 1   4       100001  simpson strong tie 12 gaug angl
# 2   5       100001  simpson strong tie 12 gaug angl
# 3   6       100001  simpson strong tie 12 gaug angl
# 4   7       100001  simpson strong tie 12 gaug angl
#
#                   search_term  prod_brand_score  prod_title_score
# 0              90deg. bracket          0.000000          0.000000
# 1             metal l bracket          0.000000          0.000000
# 2             simpson sky abl          0.333333          0.333333
# 3          simpson strong tie          0.333333          1.000000
# 4  simpson strong tie hcc 668          0.200000          0.600000

# %%
train_X = df_train[['prod_title_score','prod_brand_score']]
train_Y = df_train[['relevance']]

test_X = df_test[['prod_title_score','prod_brand_score']]

# %%
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
regr = DecisionTreeRegressor(max_depth=20)

# %%
regr.fit(train_X, train_Y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=20, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
out = (regr.predict(test_X))

# %%
len(out)
# Out:
# 166693

# %%
df_out = pd.DataFrame(columns=['id','relevance'])

# %%
df2 = pd.DataFrame({'id': [1], 'relevance': 2})
df_out = df_out.append(df2)

# %%
df_r1 = df_test[['id']]
df_r2 = pd.DataFrame(out, columns=['relevance'])
result = pd.concat([df_r1, df_r2], axis=1)
result.to_csv("results1.csv")

# %% [markdown]
# #### Part 2

# %%
len(df_train)
# Out:
# 74067

# %%
train_X = df_train[:50000][['prod_title_score','prod_brand_score']]
train_Y = df_train[:50000][['relevance']]

test_X = df_train[50000:][['prod_title_score','prod_brand_score']]
test_Y = df_train[50000:][['relevance']]

# %%
regr.fit(train_X, train_Y)
out = (regr.predict(test_X))

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(out,test_Y.relevance.values)
# Out:
# 0.27023369716129064

# %%
df_train_50k =df_train[50000:]

# %%
df_train_50k_score = pd.DataFrame(out,columns=['P_relevance'])

# %%
df_train_50k_merge = pd.concat([df_train_50k.reset_index(),df_train_50k_score], axis = 1)

# %%
df_train_50k_merge['diff'] = abs(df_train_50k_merge['P_relevance'] -  df_train_50k_merge['relevance'])

# %%
len(df_train_50k_score)
# Out:
# 24067

# %%
df_train_50k_merge.sort(columns=['diff'], ascending=[0])
# Out:
# C:\Python\WinPython-64bit-3.4.4.1\python-3.4.4.amd64\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        index      id  product_uid  \
# 13521  63521  191475       182594
# 15854  65854  198022       187480
# 8470   58470  176724       172318
# 13363  63363  191002       182258
# 2413   52413  159205       161366
# 14815  64815  195160       185328
# 23681  73681  220338       205677
# 19048  69048  207092       194625
# 3402   53402  162024       163020
# 10832  60832  183531       176980
# 18622  68622  205912       193682
# 4012   54012  163876       164147
# 18632  68632  205941       193705
# 1603   51603  156720       159889
# 18134  68134  204530       192555
# 1667   51667  156918       160006
# 14557  64557  194423       184769
# 17351  67351  202321       190809
# 86     50086  152112       157270
# 14078  64078  193015       183706
# 21461  71461  213999       200282
# 12315  62315  187886       180071
# 2038   52038  158061       160691
# 20379  70379  210852       197684
# 19305  69305  207839       195209
# 2192   52192  158507       160961
# 2246   52246  158657       161048
# 6668   56668  171455       168897
# 15708  65708  197582       187147
# 4401   54401  164922       164819
# ...      ...     ...          ...
# 5284   55284  167476       166390
# 16447  66447  199805       188840
# 5427   55427  167940       166677
# 19707  69707  209007       196152
# 1889   51889  157583       160400
# 23437  73437  219621       205048
# 23446  73446  219652       205077
# 5313   55313  167581       166442
# 5316   55316  167585       166444
# 16439  66439  199763       188807
# 18686  68686  206082       193823
# 13455  63455  191282       182470
# 17276  67276  202136       190663
# 7095   57095  172689       169676
# 23811  73811  220715       206000
# 13461  63461  191300       182479
# 16568  66568  200097       189063
# 2785   52785  160230       161966
# 12850  62850  189504       181207
# 10172  60172  181641       175666
# 5354   55354  167728       166537
# 16591  66591  200152       189106
# 15607  65607  197306       186939
# 12005  62005  187005       179416
# 17315  67315  202231       190735
# 13505  63505  191425       182563
# 20340  70340  210750       197595
# 7547   57547  173944       170485
# 11351  61351  185134       178101
# 6573   56573  171194       168723
#
#                                            product_title  \
# 13521  global door control entri ball knob lock exit ...
# 15854          alpin 15in. larg red bowl plastic planter
# 8470   green matter 3 light mahogani bronz vaniti fixtur
# 13363  home decor collect 18 xbi 34.5 xbi 21in. coven...
# 2413   rock #9 xbi 2 1/4in. phillip high low thread w...
# 14815  global goodwil coleur 6 1/2in. wide rim plate ...
# 23681  awntech 20ft. key west full cassett manual ret...
# 19048  steam spa royal 4.5 k w steam bath gener packa...
# 3402     buffalo tool fold mortar board stand discontinu
# 10832  hedrix 11oz. match ecc 36 1 shadi willow semi ...
# 18622  plantat pattern toulon floral high back outdoo...
# 4012   radion hi tech melissa 3 light satin chrome pe...
# 18632  glidden premium 1gal. #hdgr 48 blush pink sati...
# 1603   stanley 3/8in. leg xbi 1in. crown galvan steel...
# 18134        heath bird stop blue ceram wild bird feeder
# 1667   werner 14ft. fiberglass round rung straight la...
# 19305          1.000000          0.000000     2.675407  1.675407
# 2192           1.000000          0.000000     2.675407  1.675407
# 2246           1.000000          0.000000     2.675407  1.675407
# 6668           1.000000          0.000000     2.675407  1.675407
# 15708          1.000000          0.000000     2.675407  1.675407
# 4401           1.000000          1.000000     2.639302  1.639302
# ...                 ...               ...          ...       ...
# 5284           1.000000          0.000000     2.675407  0.005407
# 16447          1.000000          0.000000     2.675407  0.005407
# 5427           1.000000          0.000000     2.675407  0.005407
# 19707          1.000000          0.000000     2.675407  0.005407
# 1889           1.000000          0.000000     2.675407  0.005407
# 23437          1.000000          0.000000     2.675407  0.005407
# 23446          1.000000          0.000000     2.675407  0.005407
# 5313           1.000000          0.000000     2.675407  0.005407
# 5316           1.000000          0.000000     2.675407  0.005407
# 16439          1.000000          0.000000     2.675407  0.005407
# 18686          1.000000          0.000000     2.675407  0.005407
# 13455          1.000000          0.000000     2.675407  0.005407
# 17276          0.777778          0.111111     2.665000  0.005000
# 7095           0.800000          0.600000     2.333333  0.003333
# 23811          0.800000          0.600000     2.333333  0.003333
# 13461          0.777778          0.000000     2.333333  0.003333
# 16568          0.800000          0.600000     2.333333  0.003333
# 2785           0.800000          0.600000     2.333333  0.003333
# 12850          0.800000          0.600000     2.333333  0.003333
# 10172          0.800000          0.600000     2.333333  0.003333
# 5354           0.888889          0.000000     2.667500  0.002500
# 16591          0.428571          0.142857     2.332000  0.002000
# 15607          0.428571          0.142857     2.332000  0.002000
# 12005          0.428571          0.142857     2.332000  0.002000
# 17315          0.000000          0.250000     1.000000  0.000000
# 13505          0.571429          0.285714     2.330000  0.000000
# 20340          0.000000          0.250000     1.000000  0.000000
# 7547           0.571429          0.285714     2.330000  0.000000
# 11351          0.888889          0.111111     3.000000  0.000000
# 6573           0.500000          0.125000     2.670000  0.000000
#
# [24067 rows x 10 columns]

# %%
df_train[df_train['search_term'] == "full home"]
# Out:
#            id  product_uid                                      product_title  \
# 13783   42610       110306  home master artesian full contact permeat pump...
# 63363  191002       182258  home decor collect 18 xbi 34.5 xbi 21in. coven...
# 67351  202321       190809  home decor collect 24 xbi 34.5 xbi 24in. lewis...
# 68959  206856       194426  home dynamix jill morgan fashion print geo ora...
# 70032  209844       196830  home decor collect 21 xbi 34.5 xbi 24in. hargr...
# 70659  211666       198359  home decor collect 12 xbi 34.5 xbi 21in. lewis...
# 71356  213689       200022        kidd full home 3 a: 40 b: c fire extinguish
# 73019  218450       204026  home decor collect 24 xbi 34.5 xbi 24in. brook...
# 73963  221176       206404  lavish home ultra soft white altern full queen...
#
#       search_term  relevance  prod_title_score  prod_brand_score
# 13783   full home       1.67                 1               0.5
# 63363   full home       1.00                 1               0.5
# 67351   full home       1.00                 1               0.0
# 68959   full home       1.67                 1               0.0
# 70032   full home       2.33                 1               0.5
# 70659   full home       1.33                 1               0.0
# 71356   full home       1.67                 1               0.0
# 73019   full home       1.67                 1               0.5
# 73963   full home       2.33                 1               0.5

# %%
import nltk

# %%
nltk.pos_tag(["home"])
# Out:
# [('home', 'NN')]
